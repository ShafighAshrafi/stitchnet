# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import shutil
import numpy as np
from tqdm import tqdm
from glob import glob
from src.service.fragment.net import Net
from skl2onnx.helpers.onnx_helper import load_onnx_model
from skl2onnx.helpers.onnx_helper import save_onnx_model
from src.service.fragment.create_fragments import get_fragments
from src.utilities.change_model_layers_dimension import change_layers_dimension

# %%
x = np.random.randn(1, 3, 224, 224).astype(np.float32)

nets = []
model_names = sorted(glob('../_results_with_finetune/finetune/*/'))
for i, model in tqdm(enumerate(model_names), position=0, leave=True):
    print(model)
    model_onnx1 = load_onnx_model(model + "model_ft.onnx")
    change_layers_dimension(model_onnx1)
    fragments1 = get_fragments(model_onnx1, x)
    net1 = Net(fragments1, i)
    nets.append(net1)
# Out:
# 0it [00:00, ?it/s]
# _results/finetune/alexnet/
# ['input.1', '/features/features.2/MaxPool_output_0', '/features/features.5/MaxPool_output_0', '/features/features.7/Relu_output_0', '/features/features.9/Relu_output_0', '/Flatten_output_0', '/classifier/classifier.2/Relu_output_0', '/classifier/classifier.5/Relu_output_0']
# 0 /features/features.2/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.3/Conv']
# inputnodes 0 /features/features.2/MaxPool_output_0 1 ['Conv'] [['/features/features.2/MaxPool_output_0', 'features.3.weight', 'features.3.bias']] True
# 1 /features/features.5/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.6/Conv']
# inputnodes 1 /features/features.5/MaxPool_output_0 1 ['Conv'] [['/features/features.5/MaxPool_output_0', 'features.6.weight', 'features.6.bias']] True
# 2 /features/features.7/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.8/Conv']
# inputnodes 2 /features/features.7/Relu_output_0 1 ['Conv'] [['/features/features.7/Relu_output_0', 'features.8.weight', 'features.8.bias']] True
# 3 /features/features.9/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.10/Conv']
# inputnodes 3 /features/features.9/Relu_output_0 1 ['Conv'] [['/features/features.9/Relu_output_0', 'features.10.weight', 'features.10.bias']] True
# 4 /Flatten_output_0
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.1/Gemm']
# inputnodes 4 /Flatten_output_0 1 ['Gemm'] [['/Flatten_output_0', 'classifier.1.weight', 'classifier.1.bias']] False
# 5 /classifier/classifier.2/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.4/Gemm']
# inputnodes 5 /classifier/classifier.2/Relu_output_0 1 ['Gemm'] [['/classifier/classifier.2/Relu_output_0', 'classifier.4.weight', 'classifier.4.bias']] False
# 6 /classifier/classifier.5/Relu_output_0
# 1it [00:06,  6.32s/it]
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.6/Gemm']
# inputnodes 6 /classifier/classifier.5/Relu_output_0 1 ['Gemm'] [['/classifier/classifier.5/Relu_output_0', 'classifier.6.weight', 'classifier.6.bias']] False
# _results/finetune/densenet121/
# ['input.1', '/features/denseblock1/denselayer1/relu1/Relu_output_0', '/features/denseblock1/denselayer1/relu2/Relu_output_0', '/features/denseblock1/denselayer2/relu1/Relu_output_0', '/features/denseblock1/denselayer2/relu2/Relu_output_0', '/features/denseblock1/denselayer3/relu1/Relu_output_0', '/features/denseblock1/denselayer3/relu2/Relu_output_0', '/features/denseblock1/denselayer4/relu1/Relu_output_0', '/features/denseblock1/denselayer4/relu2/Relu_output_0', '/features/denseblock1/denselayer5/relu1/Relu_output_0', '/features/denseblock1/denselayer5/relu2/Relu_output_0', '/features/denseblock1/denselayer6/relu1/Relu_output_0', '/features/denseblock1/denselayer6/relu2/Relu_output_0', '/features/transition1/relu/Relu_output_0', '/features/denseblock2/denselayer1/relu1/Relu_output_0', '/features/denseblock2/denselayer1/relu2/Relu_output_0', '/features/denseblock2/denselayer2/relu1/Relu_output_0', '/features/denseblock2/denselayer2/relu2/Relu_output_0', '/features/denseblock2/denselayer3/relu1/Relu_output_0', '/features/denseblock2/denselayer3/relu2/Relu_output_0', '/features/denseblock2/denselayer4/relu1/Relu_output_0', '/features/denseblock2/denselayer4/relu2/Relu_output_0', '/features/denseblock2/denselayer5/relu1/Relu_output_0', '/features/denseblock2/denselayer5/relu2/Relu_output_0', '/features/denseblock2/denselayer6/relu1/Relu_output_0', '/features/denseblock2/denselayer6/relu2/Relu_output_0', '/features/denseblock2/denselayer7/relu1/Relu_output_0', '/features/denseblock2/denselayer7/relu2/Relu_output_0', '/features/denseblock2/denselayer8/relu1/Relu_output_0', '/features/denseblock2/denselayer8/relu2/Relu_output_0', '/features/denseblock2/denselayer9/relu1/Relu_output_0', '/features/denseblock2/denselayer9/relu2/Relu_output_0', '/features/denseblock2/denselayer10/relu1/Relu_output_0', '/features/denseblock2/denselayer10/relu2/Relu_output_0', '/features/denseblock2/denselayer11/relu1/Relu_output_0', '/features/denseblock2/denselayer11/relu2/Relu_output_0', '/features/denseblock2/denselayer12/relu1/Relu_output_0', '/features/denseblock2/denselayer12/relu2/Relu_output_0', '/features/transition2/relu/Relu_output_0', '/features/denseblock3/denselayer1/relu1/Relu_output_0', '/features/denseblock3/denselayer1/relu2/Relu_output_0', '/features/denseblock3/denselayer2/relu1/Relu_output_0', '/features/denseblock3/denselayer2/relu2/Relu_output_0', '/features/denseblock3/denselayer3/relu1/Relu_output_0', '/features/denseblock3/denselayer3/relu2/Relu_output_0', '/features/denseblock3/denselayer4/relu1/Relu_output_0', '/features/denseblock3/denselayer4/relu2/Relu_output_0', '/features/denseblock3/denselayer5/relu1/Relu_output_0', '/features/denseblock3/denselayer5/relu2/Relu_output_0', '/features/denseblock3/denselayer6/relu1/Relu_output_0', '/features/denseblock3/denselayer6/relu2/Relu_output_0', '/features/denseblock3/denselayer7/relu1/Relu_output_0', '/features/denseblock3/denselayer7/relu2/Relu_output_0', '/features/denseblock3/denselayer8/relu1/Relu_output_0', '/features/denseblock3/denselayer8/relu2/Relu_output_0', '/features/denseblock3/denselayer9/relu1/Relu_output_0', '/features/denseblock3/denselayer9/relu2/Relu_output_0', '/features/denseblock3/denselayer10/relu1/Relu_output_0', '/features/denseblock3/denselayer10/relu2/Relu_output_0', '/features/denseblock3/denselayer11/relu1/Relu_output_0', '/features/denseblock3/denselayer11/relu2/Relu_output_0', '/features/denseblock3/denselayer12/relu1/Relu_output_0', '/features/denseblock3/denselayer12/relu2/Relu_output_0', '/features/denseblock3/denselayer13/relu1/Relu_output_0', '/features/denseblock3/denselayer13/relu2/Relu_output_0', '/features/denseblock3/denselayer14/relu1/Relu_output_0', '/features/denseblock3/denselayer14/relu2/Relu_output_0', '/features/denseblock3/denselayer15/relu1/Relu_output_0', '/features/denseblock3/denselayer15/relu2/Relu_output_0', '/features/denseblock3/denselayer16/relu1/Relu_output_0', '/features/denseblock3/denselayer16/relu2/Relu_output_0', '/fe ...
# 0 /features/denseblock1/denselayer1/relu1/Relu_output_0
# 1 /features/denseblock1/denselayer1/relu2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# 2 /features/denseblock1/denselayer2/relu1/Relu_output_0
# 3 /features/denseblock1/denselayer2/relu2/Relu_output_0
# 4 /features/denseblock1/denselayer3/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# 5 /features/denseblock1/denselayer3/relu2/Relu_output_0
# 6 /features/denseblock1/denselayer4/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# 7 /features/denseblock1/denselayer4/relu2/Relu_output_0
# 8 /features/denseblock1/denselayer5/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# 9 /features/denseblock1/denselayer5/relu2/Relu_output_0
# 10 /features/denseblock1/denselayer6/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# 11 /features/denseblock1/denselayer6/relu2/Relu_output_0
# 12 /features/transition1/relu/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input input.1 is undefined!
# len(get_input_nodes(newf1)) 1 ['/features/transition1/conv/Conv']
# inputnodes 12 /features/transition1/relu/Relu_output_0 1 ['Conv'] [['/features/transition1/relu/Relu_output_0', 'features.transition1.conv.weight']] True
# 13 /features/denseblock2/denselayer1/relu1/Relu_output_0
# 14 /features/denseblock2/denselayer1/relu2/Relu_output_0
# 15 /features/denseblock2/denselayer2/relu1/Relu_output_0
# 16 /features/denseblock2/denselayer2/relu2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 17 /features/denseblock2/denselayer3/relu1/Relu_output_0
# 18 /features/denseblock2/denselayer3/relu2/Relu_output_0
# 19 /features/denseblock2/denselayer4/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 20 /features/denseblock2/denselayer4/relu2/Relu_output_0
# 21 /features/denseblock2/denselayer5/relu1/Relu_output_0
# 22 /features/denseblock2/denselayer5/relu2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 23 /features/denseblock2/denselayer6/relu1/Relu_output_0
# 24 /features/denseblock2/denselayer6/relu2/Relu_output_0
# 25 /features/denseblock2/denselayer7/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 26 /features/denseblock2/denselayer7/relu2/Relu_output_0
# 27 /features/denseblock2/denselayer8/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 28 /features/denseblock2/denselayer8/relu2/Relu_output_0
# 29 /features/denseblock2/denselayer9/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 30 /features/denseblock2/denselayer9/relu2/Relu_output_0
# 31 /features/denseblock2/denselayer10/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 32 /features/denseblock2/denselayer10/relu2/Relu_output_0
# 33 /features/denseblock2/denselayer11/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 34 /features/denseblock2/denselayer11/relu2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 35 /features/denseblock2/denselayer12/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 36 /features/denseblock2/denselayer12/relu2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition1/relu/Relu_output_0 is undefined!
# 37 /features/transition2/relu/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/transition2/conv/Conv']
# inputnodes 37 /features/transition2/relu/Relu_output_0 1 ['Conv'] [['/features/transition2/relu/Relu_output_0', 'features.transition2.conv.weight']] True
# 38 /features/denseblock3/denselayer1/relu1/Relu_output_0
# 39 /features/denseblock3/denselayer1/relu2/Relu_output_0
# 40 /features/denseblock3/denselayer2/relu1/Relu_output_0
# 41 /features/denseblock3/denselayer2/relu2/Relu_output_0
# 42 /features/denseblock3/denselayer3/relu1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /features/transition2/relu/Relu_output_0 is undefined!
# 43 /features/denseblock3/denselayer3/relu2/Relu_output_0
# 44 /features/denseblock3/denselayer4/relu1/Relu_output_0
# 45 /features/denseblock3/denselayer4/relu2/Relu_output_0
# ...
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer2/layer2.3/relu_2/Relu_output_0 is undefined!
# 36 /layer3/layer3.3/relu_2/Relu_output_0
# len(get_input_nodes(newf1)) 2 ['/layer3/layer3.4/conv1/Conv', '/layer3/layer3.4/Add']
# inputnodes 36 /layer3/layer3.3/relu_2/Relu_output_0 2 ['Conv', 'Add'] [['/layer3/layer3.3/relu_2/Relu_output_0', 'onnx::Conv_608', 'onnx::Conv_609'], ['/layer3/layer3.4/conv3/Conv_output_0', '/layer3/layer3.3/relu_2/Relu_output_0']] False
# 37 /layer3/layer3.4/relu/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer2/layer2.3/relu_2/Relu_output_0 is undefined!
# 38 /layer3/layer3.4/relu_1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer2/layer2.3/relu_2/Relu_output_0 is undefined!
# 39 /layer3/layer3.4/relu_2/Relu_output_0
# len(get_input_nodes(newf1)) 2 ['/layer3/layer3.5/conv1/Conv', '/layer3/layer3.5/Add']
# inputnodes 39 /layer3/layer3.4/relu_2/Relu_output_0 2 ['Conv', 'Add'] [['/layer3/layer3.4/relu_2/Relu_output_0', 'onnx::Conv_617', 'onnx::Conv_618'], ['/layer3/layer3.5/conv3/Conv_output_0', '/layer3/layer3.4/relu_2/Relu_output_0']] False
# 40 /layer3/layer3.5/relu/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer2/layer2.3/relu_2/Relu_output_0 is undefined!
# 41 /layer3/layer3.5/relu_1/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer2/layer2.3/relu_2/Relu_output_0 is undefined!
# 42 /layer3/layer3.5/relu_2/Relu_output_0
# len(get_input_nodes(newf1)) 2 ['/layer4/layer4.0/conv1/Conv', '/layer4/layer4.0/downsample/downsample.0/Conv']
# inputnodes 42 /layer3/layer3.5/relu_2/Relu_output_0 2 ['Conv', 'Conv'] [['/layer3/layer3.5/relu_2/Relu_output_0', 'onnx::Conv_626', 'onnx::Conv_627'], ['/layer3/layer3.5/relu_2/Relu_output_0', 'onnx::Conv_635', 'onnx::Conv_636']] True
# 43 /layer4/layer4.0/relu/Relu_output_0
# 44 /layer4/layer4.0/relu_1/Relu_output_0
# 45 /layer3/layer3.5/relu_2/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# len(get_input_nodes(newf1)) 2 ['/layer4/layer4.0/conv1/Conv', '/layer4/layer4.0/downsample/downsample.0/Conv']
# 46 /layer4/layer4.0/relu_2/Relu_output_0
# len(get_input_nodes(newf1)) 2 ['/layer4/layer4.1/conv1/Conv', '/layer4/layer4.1/Add']
# inputnodes 46 /layer4/layer4.0/relu_2/Relu_output_0 2 ['Conv', 'Add'] [['/layer4/layer4.0/relu_2/Relu_output_0', 'onnx::Conv_638', 'onnx::Conv_639'], ['/layer4/layer4.1/conv3/Conv_output_0', '/layer4/layer4.0/relu_2/Relu_output_0']] False
# 47 /layer4/layer4.1/relu/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# 48 /layer4/layer4.1/relu_1/Relu_output_0
# 49 /layer4/layer4.1/relu_2/Relu_output_0
# len(get_input_nodes(newf1)) 2 ['/layer4/layer4.2/conv1/Conv', '/layer4/layer4.2/Add']
# inputnodes 49 /layer4/layer4.1/relu_2/Relu_output_0 2 ['Conv', 'Add'] [['/layer4/layer4.1/relu_2/Relu_output_0', 'onnx::Conv_647', 'onnx::Conv_648'], ['/layer4/layer4.2/conv3/Conv_output_0', '/layer4/layer4.1/relu_2/Relu_output_0']] False
# 50 /layer4/layer4.2/relu/Relu_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# 51 /layer4/layer4.2/relu_1/Relu_output_0
# 52 /Flatten_output_0
# Traceback (most recent call last):
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/create_fragments.py", line 25, in get_fragments
#     first_part_model, remaining_model, first_part_output = split_model_at(model, inp, input[0], str(i))
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/split_model.py", line 14, in split_model_at
#     remaining_model = select_model_inputs_outputs2(
#   File "/home/shafigh/Desktop/projects/stitchnet/src/service/fragment/select_input_output.py", line 139, in select_model_inputs_outputs2
#     optimized_model = onnxoptimizer.optimize(onnx_model, passes)
#   File "/home/shafigh/Desktop/projects/stitchnet/.stitchnet/lib/python3.10/site-packages/onnxoptimizer/__init__.py", line 46, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input /layer3/layer3.5/relu_2/Relu_output_0 is undefined!
# 4it [00:41, 11.11s/it]
# len(get_input_nodes(newf1)) 1 ['/fc/Gemm']
# inputnodes 52 /Flatten_output_0 1 ['Gemm'] [['/Flatten_output_0', 'fc.weight', 'fc.bias']] False
# _results/finetune/vgg16/
# ['input.1', '/features/features.1/Relu_output_0', '/features/features.4/MaxPool_output_0', '/features/features.6/Relu_output_0', '/features/features.9/MaxPool_output_0', '/features/features.11/Relu_output_0', '/features/features.13/Relu_output_0', '/features/features.16/MaxPool_output_0', '/features/features.18/Relu_output_0', '/features/features.20/Relu_output_0', '/features/features.23/MaxPool_output_0', '/features/features.25/Relu_output_0', '/features/features.27/Relu_output_0', '/Flatten_output_0', '/classifier/classifier.1/Relu_output_0', '/classifier/classifier.4/Relu_output_0']
# 0 /features/features.1/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.2/Conv']
# inputnodes 0 /features/features.1/Relu_output_0 1 ['Conv'] [['/features/features.1/Relu_output_0', 'features.2.weight', 'features.2.bias']] True
# 1 /features/features.4/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.5/Conv']
# inputnodes 1 /features/features.4/MaxPool_output_0 1 ['Conv'] [['/features/features.4/MaxPool_output_0', 'features.5.weight', 'features.5.bias']] True
# 2 /features/features.6/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.7/Conv']
# inputnodes 2 /features/features.6/Relu_output_0 1 ['Conv'] [['/features/features.6/Relu_output_0', 'features.7.weight', 'features.7.bias']] True
# 3 /features/features.9/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.10/Conv']
# inputnodes 3 /features/features.9/MaxPool_output_0 1 ['Conv'] [['/features/features.9/MaxPool_output_0', 'features.10.weight', 'features.10.bias']] True
# 4 /features/features.11/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.12/Conv']
# inputnodes 4 /features/features.11/Relu_output_0 1 ['Conv'] [['/features/features.11/Relu_output_0', 'features.12.weight', 'features.12.bias']] True
# 5 /features/features.13/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.14/Conv']
# inputnodes 5 /features/features.13/Relu_output_0 1 ['Conv'] [['/features/features.13/Relu_output_0', 'features.14.weight', 'features.14.bias']] True
# 6 /features/features.16/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.17/Conv']
# inputnodes 6 /features/features.16/MaxPool_output_0 1 ['Conv'] [['/features/features.16/MaxPool_output_0', 'features.17.weight', 'features.17.bias']] True
# 7 /features/features.18/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.19/Conv']
# inputnodes 7 /features/features.18/Relu_output_0 1 ['Conv'] [['/features/features.18/Relu_output_0', 'features.19.weight', 'features.19.bias']] True
# 8 /features/features.20/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.21/Conv']
# inputnodes 8 /features/features.20/Relu_output_0 1 ['Conv'] [['/features/features.20/Relu_output_0', 'features.21.weight', 'features.21.bias']] True
# 9 /features/features.23/MaxPool_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.24/Conv']
# inputnodes 9 /features/features.23/MaxPool_output_0 1 ['Conv'] [['/features/features.23/MaxPool_output_0', 'features.24.weight', 'features.24.bias']] True
# 10 /features/features.25/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.26/Conv']
# inputnodes 10 /features/features.25/Relu_output_0 1 ['Conv'] [['/features/features.25/Relu_output_0', 'features.26.weight', 'features.26.bias']] True
# 11 /features/features.27/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/features/features.28/Conv']
# inputnodes 11 /features/features.27/Relu_output_0 1 ['Conv'] [['/features/features.27/Relu_output_0', 'features.28.weight', 'features.28.bias']] True
# 12 /Flatten_output_0
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.0/Gemm']
# inputnodes 12 /Flatten_output_0 1 ['Gemm'] [['/Flatten_output_0', 'classifier.0.weight', 'classifier.0.bias']] False
# 13 /classifier/classifier.1/Relu_output_0
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.3/Gemm']
# inputnodes 13 /classifier/classifier.1/Relu_output_0 1 ['Gemm'] [['/classifier/classifier.1/Relu_output_0', 'classifier.3.weight', 'classifier.3.bias']] False
# 14 /classifier/classifier.4/Relu_output_0
# 5it [01:09, 13.97s/it]
# len(get_input_nodes(newf1)) 1 ['/classifier/classifier.6/Gemm']
# inputnodes 14 /classifier/classifier.4/Relu_output_0 1 ['Gemm'] [['/classifier/classifier.4/Relu_output_0', 'classifier.6.weight', 'classifier.6.bias']] False

# %%
for net in nets:
    print("number of fragments", len(net))
# Out:
# number of fragments 8
# number of fragments 5
# number of fragments 13
# number of fragments 6
# number of fragments 16

# %%
shutil.rmtree("_results_with_finetune/fragments", ignore_errors=True)
os.makedirs("_results_with_finetune/fragments", exist_ok=True)
for i,net in enumerate(nets):
    for j,fragment in enumerate(net):
        folder = f"_results_with_finetune/fragments/net{i:03}/"
        os.makedirs(folder, exist_ok = True)
        filename = folder+f'fragment{j:03}.onnx'
        save_onnx_model(fragment.fragment, filename)
